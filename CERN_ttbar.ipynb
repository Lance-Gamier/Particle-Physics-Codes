# %% [markdown]
# <a href="https://colab.research.google.com/github/Lance-Gamier/Particle-Physics-Codes/blob/main/CERN_ttbar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Package First. Run only once, no need to Rerun.

# %%
# In Google Colab
# !pip install -q condacolab
import condacolab
condacolab.install()

# Restart kernel after this cell, then continue:
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !pip install uproot

# %%
# !pip install awkward-pandas

# %%
# !pip install pyhepmc

# %%
# !git clone https://github.com/scikit-hep/pyhepmc-ng.git
# !cd pyhepmc-ng
# Out:
# Cloning into 'pyhepmc-ng'...
# fatal: could not read Username for 'https://github.com': No such device or address
# /bin/bash: line 1: cd: pyhepmc-ng: No such file or directory

# %% [markdown]
# # Sample Code

# %%
# !wget https://opendata.cern.ch/record/204/files/ttbar.root # Download the file
import uproot
import pandas as pd

# Open the downloaded file locally
file = uproot.open("ttbar.root")  # Change to the name of the downloaded file

# Inspect what trees/keys are inside
file.keys()
# Out:
# --2025-05-08 15:37:27--  https://opendata.cern.ch/record/204/files/ttbar.root
# Resolving opendata.cern.ch (opendata.cern.ch)... 137.138.6.31, 2001:1458:201:8b::100:1c8
# Connecting to opendata.cern.ch (opendata.cern.ch)|137.138.6.31|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5492946 (5.2M) [application/octet-stream]
# Saving to: ‘ttbar.root.2’
#
# ttbar.root.2        100%[===================>]   5.24M  1.44MB/s    in 3.6s
#
# 2025-05-08 15:37:32 (1.44 MB/s) - ‘ttbar.root.2’ saved [5492946/5492946]
# ['events;1']

# %%
import pandas as pd

ttbar = file["events"].arrays(library = "pd")
ttbar
# Out:
#        NJet                                             Jet_Px  \
# 0         3  [14.53632640838623, -22.59884262084961, 47.944...
# 1         6  [28.4417724609375, -56.91559600830078, 33.1661...
# 2         4  [-16.001388549804688, -41.80726623535156, 29.1...
# 3         2             [-40.803672790527344, 37.520751953125]
# 4         3  [-67.60134887695312, 70.14259338378906, 27.341...
# ...     ...                                                ...
# 36936     4  [130.75238037109375, -88.65655517578125, 52.05...
# 36937     7  [103.32671356201172, -76.9673080444336, -1.773...
# 36938     1                                [9.455872535705566]
# 36939     3  [34.38261795043945, -40.78350830078125, 38.387...
# 36940     3  [1.2887529134750366, 54.24991226196289, -54.32...
#
#                                                   Jet_Py  \
# 0      [81.2174301147461, -57.128604888916016, -11.35...
# 1      [-77.40626525878906, 27.354970932006836, 53.65...
# ...
